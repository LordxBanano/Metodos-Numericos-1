# %% [markdown]
# # Gráfica de $f(x)=x - 3^{-x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def g(x):
  return x

def h(x):
  return -3**(-x)

# Función cuadrática.
def f(x):
  return x - 3**(-x)

# %%
f(-5), f(1)
# Out:
# (-248, 0.6666666666666667)

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-5, 5,100)

# %%
# Graficar ambas funciones.
plt.figure(figsize=(15,15)) #Tamaño de la figura
plt.plot(x, f(x))
plt.plot(x, g(x))
plt.plot(x, h(x))
plt.axhline(0, color="black")
plt.axvline(0, color="black")
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.savefig("output.png") # Guardar gráfico como imágen PNG.
# Mostrarlo.

plt.grid(color="gray") #Color de la malla
plt.title("Gráfica de $f(x)=x - 3^{-x}$") #Titulo del grafo
plt.xlabel("Eje X") #Rotulo del eje x
plt.ylabel("Eje Y") #Rotulo del eje y


#plt.figtext(1,1, "g(x) (trazo naranja), h(x) (trazo verde) y f(x) (trazo verde)", ha="center", fontsize="12", color="blue")


plt.show() #Muestra el grafo

# %% [markdown]
# ### Visualización gráfica:
# - La gráfica de $ g(x) $ es una línea recta con pendiente 1.
# - La gráfica de $ h(x) $ es una curva exponencial que decrece a medida que $ x $ aumenta.
# - La gráfica de $ f(x) = x - 3^{-x} $ comienza muy abajo cuando $ x $ es negativo (debido a que $ h(x) $ crece exponencialmente), pasa por $ f(0) = -1 $, y luego se aproxima a la línea recta $ g(x) $ conforme $ x $ aumenta (ya que $ h(x) $ tiende a cero).
#
# Este comportamiento es lo que da origen a la gráfica de $ f(x) $, que es una combinación de la recta $ g(x) $ y la curva decreciente $ h(x) $.

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.
#
# 1.   Elemento de lista
# 2.   Elemento de lista
